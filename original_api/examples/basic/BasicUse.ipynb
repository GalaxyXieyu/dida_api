# %% [markdown]
# ## 账号登录

# %%
# !pip install --upgrade didatodolist --index-url https://pypi.org/simple
# Out:
# DEPRECATION: Loading egg at /data/anaconda3/lib/python3.12/site-packages/edcc-0.2.1-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: didatodolist in /data/xieyu/Teaching/dida (0.1.25)
# Requirement already satisfied: requests>=2.25.0 in /data/anaconda3/lib/python3.12/site-packages (from didatodolist) (2.32.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /data/anaconda3/lib/python3.12/site-packages (from didatodolist) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.1 in /data/anaconda3/lib/python3.12/site-packages (from didatodolist) (2024.1)
# Requirement already satisfied: six>=1.5 in /data/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.0->didatodolist) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /data/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->didatodolist) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /data/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->didatodolist) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->didatodolist) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /data/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->didatodolist) (2024.8.30)

# %%
from dida import DidaClient
client = DidaClient(email="523018705@qq.com", password="X1i2e3y4u5")
token = client.token

# %%
tasks = client.tasks.get_this_week_tasks()
tasks
# Out:
# {'completed': [{'id': '67b61f4f596486bc59febada',
#    'title': 'ppt',
#    'content': '',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-21 16:00:00',
#    'dueDate': '2025-02-21 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 23:53:36',
#    'createdTime': '2025-02-19 18:13:35',
#    'completedTime': '2025-02-22 23:53:36',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'p000ukp2',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339500248288},
#   {'id': '67b61f44596486bc59febac0',
#    'title': '模板',
#    'content': '',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-21 16:00:00',
#    'dueDate': '2025-02-21 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 23:53:35',
#    'createdTime': '2025-02-19 18:13:24',
#    'completedTime': '2025-02-22 23:53:35',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'rpqerbjh',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339446561198},
#   {'id': '67b61f4a596486bc59febacd',
#    'title': '截图',
#    'content': '',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 23:53:35',
#    'createdTime': '2025-02-19 18:13:30',
#    'completedTime': '2025-02-22 23:53:35',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'gw9xubzh',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339473404743},
#   {'id': '67b61f23596486bc59feba85',
#    'title': 'refly 体验教程',
#    'content': '定位：\r\n',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-21 16:00:00',
#    'dueDate': '2025-02-21 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 23:53:14',
#    'createdTime': '2025-02-19 18:12:51',
#    'completedTime': '2025-02-22 23:53:14',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'zzgwnnbc',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339258656377},
#   {'id': '67b6b840150254081d7fc187',
#    'title': '作用',
#    'content': '',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-20 16:00:00',
#    'dueDate': '2025-02-20 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-21 08:14:41',
#    'createdTime': '2025-02-20 05:06:08',
#    'completedTime': '2025-02-22 23:53:14',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '3i4op03z',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339258721913},
#   {'id': '67b6b844150254081d7fc197',
#    'title': '功能特点',
#    'content': '',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-20 16:00:00',
#    'dueDate': '2025-02-20 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-21 08:14:45',
#    'createdTime': '2025-02-20 05:06:12',
#    'completedTime': '2025-02-22 23:53:14',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'wgk77qf9',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339258787449},
#   {'id': '67b6b853150254081d7fc1a6',
#    'title': '侧边栏能力',
#    'content': '',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-20 16:00:00',
#    'dueDate': '2025-02-20 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-21 08:14:49',
#    'createdTime': '2025-02-20 05:06:27',
#    'completedTime': '2025-02-22 23:53:14',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '2h6e1thx',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339258852985},
#   {'id': '67b6b88b150254081d7fc1bb',
#    'title': '标题',
#    'content': 'Refly ',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-20 16:00:00',
#    'dueDate': '2025-02-20 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-21 08:14:53',
#    'createdTime': '2025-02-20 05:07:23',
#    'completedTime': '2025-02-22 23:53:14',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '3da5ld0o',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339258918521},
#   {'id': '67b61272e37d5c0000000109',
#    'title': '任务分配操作',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-21 16:00:00',
#    'dueDate': '2025-02-21 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 05:23:20',
#    'createdTime': '2025-02-19 17:18:42',
#    'completedTime': '2025-02-22 05:23:20',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'v4q5t185',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 1073741824},
#   {'id': '67b61ea4596486bc59feba20',
#    'title': 'coze 工作流优化',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-21 08:14:34',
#    'createdTime': '2025-02-19 18:10:44',
#    'completedTime': '2025-02-21 08:14:34',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'wkthsyt7',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339258590841},
#   {'id': '67b18924ebad9a0001000147',
#    'title': '整理deepseek相关资料的组成部分',
#    'content': '',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '65db218c7ae46e15dac5def8',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-20 05:03:39',
#    'createdTime': '2025-02-16 06:43:48',
#    'completedTime': '2025-02-20 05:03:39',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'uyjhmsv0',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2336842278521},
#   {'id': '67b195a8ebad9a00010001d7',
#    'title': '接入deepseek',
#    'content': '',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-20 05:03:29',
#    'createdTime': '2025-02-16 07:37:12',
#    'completedTime': '2025-02-20 05:03:29',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'us9aa59w',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 268435456},
#   {'id': '67b60954e37d5c00000000cf',
#    'title': '添加任务的操作是否正确',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-19 17:18:26',
#    'createdTime': '2025-02-19 16:39:48',
#    'completedTime': '2025-02-19 17:18:26',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'ko4o6zo3',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 536870912},
#   {'id': '67b42ff0e37d5c0000000739',
#    'title': '查询任务的常规操作',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-18 16:00:00',
#    'dueDate': '2025-02-18 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-19 16:39:45',
#    'createdTime': '2025-02-18 07:00:00',
#    'completedTime': '2025-02-19 16:39:45',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '34fljyp4',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 268435456},
#   {'id': '67b3cc237ae405afde6e2ead',
#    'title': '配置 dbgpt 的 deepseek 版本',
#    'content': '',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-17 16:00:00',
#    'dueDate': '2025-02-17 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '65db218c7ae46e15dac5def8',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-18 11:56:54',
#    'createdTime': '2025-02-17 23:54:11',
#    'completedTime': '2025-02-18 11:56:54',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'weoj8wo6',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2338184783481},
#   {'id': '67b3e115e37d5c00000005ce',
#    'title': '一个idea内容很多如何转化成多个idea视频',
#    'content': '',
#    'priority': 3,
#    'status': 2,
#    'startDate': '2025-02-17 16:00:00',
#    'dueDate': '2025-02-17 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-18 11:55:59',
#    'createdTime': '2025-02-18 01:23:33',
#    'completedTime': '2025-02-18 11:55:59',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'h6ysp7j1',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2338721654393},
#   {'id': '67b3e09de37d5c00000005c4',
#    'title': '积木玩具抠图',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-17 16:00:00',
#    'dueDate': '2025-02-17 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-18 03:51:33',
#    'createdTime': '2025-02-18 01:21:33',
#    'completedTime': '2025-02-18 03:51:33',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'xiqje1ph',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2338453218937},
#   {'id': '67b3e132e37d5c00000005da',
#    'title': '出差流程沟通',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-17 16:00:00',
#    'dueDate': '2025-02-17 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-18 03:28:10',
#    'createdTime': '2025-02-18 01:24:02',
#    'completedTime': '2025-02-18 03:28:10',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'apv8ztdk',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2338990089849},
#   {'id': '67b1d3cf8ef81fe866966953',
#    'title': '滴答清单插件优化',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 16:22:05',
#    'createdTime': '2025-02-16 12:02:23',
#    'completedTime': '2025-02-17 16:22:00',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'x4i6mnwy',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2337647847033},
#   {'id': '67b1898cebad9a0001000152',
#    'title': 'AI信息整理工作流',
#    'content': '',
#    'priority': 3,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 15:27:01',
#    'createdTime': '2025-02-16 06:45:32',
#    'completedTime': '2025-02-17 15:27:01',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'bv41g5l2',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 536870912},
#   {'id': '67b18d8bebad9a0001000197',
#    'title': 'bilibili',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 15:27:00',
#    'createdTime': '2025-02-16 07:02:35',
#    'completedTime': '2025-02-17 15:27:00',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'i63fs4c7',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 536870912},
#   {'id': '67b18d27ebad9a000100018a',
#    'title': 'huggingface Trending',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 15:26:59',
#    'createdTime': '2025-02-16 07:00:55',
#    'completedTime': '2025-02-17 15:26:59',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'xwgeea44',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 268435456},
#   {'id': '67b18d1febad9a0001000187',
#    'title': 'github Trending',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 15:26:58',
#    'createdTime': '2025-02-16 07:00:47',
#    'completedTime': '2025-02-17 15:26:58',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '2b83a7un',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 268435456},
#   {'id': '67b303e4e37d5c0000000515',
#    'title': '阅读30分钟',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '65db218c7ae46e15dac5def8',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 15:26:55',
#    'createdTime': '2025-02-17 09:39:48',
#    'completedTime': '2025-02-17 15:26:55',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'hhd33afu',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2337916348025},
#   {'id': '67b1d3a78ef81fe86696691c',
#    'title': '濠江知识库优化',
#    'content': '',
#    'priority': 3,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 09:39:46',
#    'createdTime': '2025-02-16 12:01:43',
#    'completedTime': '2025-02-17 09:39:46',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'pjhkkp7g',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2337647781497},
#   {'id': '67b1d3bf8ef81fe866966941',
#    'title': 'dify 优化',
#    'content': '',
#    'priority': 3,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 09:39:44',
#    'createdTime': '2025-02-16 12:02:07',
#    'completedTime': '2025-02-17 09:39:44',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'pcyo41en',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2337647912569},
#   {'id': '67b1d37a8ef81fe8669668f8',
#    'title': '知识库数据预处理',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 09:39:36',
#    'createdTime': '2025-02-16 12:00:58',
#    'completedTime': '2025-02-17 09:39:36',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'zm4i4la7',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2337647715961},
#   {'id': '67b1d1b18ef81fe866966893',
#    'title': '产业顾问接口拆分',
#    'content': '',
#    'priority': 5,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '4024428bac6d182ac68da936',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-17 06:25:59',
#    'createdTime': '2025-02-16 11:53:21',
#    'completedTime': '2025-02-17 06:25:59',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '2blm76ox',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2337647650425},
#   {'id': '67ba6389ebad9a0000000212',
#    'title': '微调方式',
#    'content': '## Alpaca：\ninstruction：怎么回答\ninput：问题\noutput：输出\n\n# 预训练（无监督）\n[\n  {"text": "document"},\n  {"text": "document"}\n]\n\n# DPO和ORPO训练：提供一个正确回复和一个错误回复\n[\n  {\n    "instruction": "人类指令（必填）",\n    "input": "人类输入（选填）",\n    "chosen": "优质回答（必填）",\n    "rejected": "劣质回答（必填）"\n  }\n]\n\n# KTO数据集：提供一个机器答案和人类评分\n\n',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-22 16:00:00',
#    'dueDate': '2025-02-22 16:00:00',
#    'projectId': '6669cdd9ebad9a000000039c',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22T23:53:46.934+0000',
#    'createdTime': '2025-02-22 23:53:45',
#    'completedTime': '2025-02-22 23:53:45',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '1pfyhxm2',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 9131261952},
#   {'id': '67b6b792150254081d7fc122',
#    'title': '知识库常见问题',
#    'content': '1. 知识库内容缺失\n2. TopK截断有用文档\n3. 上下文整合丢失\n4. 有用信息未识别\n5. 提示词格式问题\n6. 准确性不足\n7. 答案不完整\n\n解决方法：\n问题1-3：属于知识库工程层面的问题，可以通过完善知识库、增强知识确定性、优化上下文整合策略解决。\n问题4-6：属于大模型自身能力的问题，依赖大模型的训练和迭代。\n问题7：属于RAG架构问题，更有前景的思路是使用Agent引入规划能力。',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectId': '6669cdd9ebad9a000000039c',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-20T05:03:15.150+0000',
#    'createdTime': '2024-07-24 07:50:43',
#    'completedTime': '2025-02-20 05:03:14',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'yqssd6io',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 524288},
#   {'id': '67b61dca596486bc59feb9e6',
#    'title': '单例模式',
#    'content': '单例模式总结\n一、概念\n确保一个类只有一个实例，且提供全局访问点获取该实例。\n二、实现方式\n懒汉式 - 线程不安全：延迟实例化，多线程下可能多次实例化，少用于多线程场景。\n饿汉式 - 线程安全：类加载时实例化，线程安全但可能浪费资源。\n懒汉式 - 线程安全（加锁）：方法加锁保证线程安全，但性能差。\n双重校验锁 - 线程安全：两次检查和加锁，性能和安全兼顾。\n静态内部类实现：延迟初始化且线程安全，较优雅。\n枚举实现：安全性高，防止反射和序列化问题。\n三、AI 模型场景\n建议用双重校验锁或静态内部类实现。模型初始化耗时长、资源多，这两种方式能在保证线程安全（如果有多线程需求）的情况下高效利用资源或延迟初始化。\n\n\n设计模式是什么？\n设计模式描述了对象之间如何在不干扰彼此数据模型和方法的情况下进行通信。',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectId': '6669cdd9ebad9a000000039c',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-19T18:07:10.714+0000',
#    'createdTime': '2024-10-23 09:50:17',
#    'completedTime': '2025-02-19 18:07:06',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'dqsc03ai',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 8996913152},
#   {'id': '67b61dbc596486bc59feb9d5',
#    'title': '代码命名规范',
#    'content': '![image](67b61dbc596486bc59feb9d6/66ef9138ebad9a00020006ef.png)\n',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectId': '6669cdd9ebad9a000000039c',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-19T18:06:54.339+0000',
#    'createdTime': '2024-09-22 03:37:03',
#    'completedTime': '2025-02-19 18:06:52',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '6pgke5gs',
#    'deleted': 0,
#    'attachments': [{'id': '67b61dbc596486bc59feb9d6',
#      'refId': '66ef9138ebad9a00020006f0',
#      'size': 37083,
#      'fileName': '66ef9138ebad9a00020006ef.png',
#      'fileType': 'IMAGE',
#      'status': 0,
#      'createdTime': '2025-02-19T18:06:52.000+0000'}],
#    'imgMode': 0,
#    'sortOrder': 13422100480},
#   {'id': '67b61d97596486bc59feb9c6',
#    'title': 'embeding模型维度选择的重要性还有如何适配对应的向量库',
#    'content': '以下是关于FAISS向量库和嵌入模型维度的知识总结：\n1. 嵌入模型的维度\n定义：嵌入模型将文本或其他数据转换为固定维度的向量。例如，使用OpenAI的嵌入模型时，输出的向量维度通常是预先设定的，如768D或1536D。\n选择维度的重要性：选择合适的维度对于捕捉数据特征至关重要。高维向量能够表达更复杂的信息，但会增加计算负担；低维向量则计算更快，但可能丢失信息。\n2. FAISS索引的基本概念\nFAISS简介：FAISS（Facebook AI Similarity Search）是一个高效的相似性搜索库，能够处理大量高维向量。它支持多种索引类型，适用于不同规模和需求的应用。\n固定维度要求：FAISS要求所有存储的向量具有相同的固定维度。在创建索引时，必须指定该维度。\n3. 常见索引类型\nIndexFlatL2：\n特点：使用欧氏距离进行暴力检索，适合小规模数据集。\n优缺点：精确但速度较慢，不需要训练步骤。\nIndexIVFFlat：\n特点：使用聚类方法加速检索。需要训练阶段来建立聚类中心。\n参数：\nnlist：聚类单元数量。\nnprobe：查询时要搜索的单元数量。\nIndexIVFPQ：\n特点：基于产品量化的方法，适合大规模数据集，能够压缩存储。\n参数：\nm：子量化器数量。\nn_bits：每个子量化器分配的位数。\n4. 实际应用中的注意事项\n维度匹配：在使用FAISS时，确保嵌入模型输出的向量维度与FAISS索引的维度一致，以避免错误和不准确的检索结果。\n选择合适的索引类型：根据数据规模、查询速度和精确度需求选择合适的索引类型，以平衡性能和效率。',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectId': '6669cdd9ebad9a000000039c',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-19 18:06:15',
#    'createdTime': '2024-10-21 04:24:59',
#    'completedTime': '2025-02-19 18:06:15',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'wwom9vqz',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 12616728576},
#   {'id': '67b6094ce37d5c00000000bd',
#    'title': 'embeding模型的缺陷',
#    'content': '1. 有限的语义限制：在两个句子非常相似只有个别时间和情感的区别上，embeding模型无法区分\r\n2. 维度限制：有限制在512*1024上运行导致对长文本的支持不足\r\n3. 泛化问题：对特定资料进行训练的，比较难以泛化，很难适应用户的动态查询\n4. 对于整体的长文本理解存在天生缺陷，因为每次只是检索知识块',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-20 16:00:00',
#    'dueDate': '2025-02-20 16:00:00',
#    'projectId': '6669cdd9ebad9a000000039c',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-19T16:39:45.232+0000',
#    'createdTime': '2025-02-19 16:39:40',
#    'completedTime': '2025-02-19 16:39:40',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '9z5sazkn',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 458816},
#   {'id': '67b3cc387ae405afde6e2ebb',
#    'title': '整理优化需求文档助手',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-17 16:00:00',
#    'dueDate': '2025-02-17 16:00:00',
#    'projectId': '6669cdd9ebad9a000000039c',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-18 03:51:55',
#    'createdTime': '2025-02-17 23:54:32',
#    'completedTime': '2025-02-18 03:51:55',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'sedu9umd',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2213250596864},
#   {'id': '67b3e088e37d5c00000005b5',
#    'title': 'langgraph学习感受',
#    'content': '定义：通过构建AI的地图，配置每一个节点来执行agent的流程，更加方面和模块化\r\n\r\n1. 可以定义每个作用不同的agent是一个node，然后记录在一个state的临时变量里面\r\n2. 通过每个模型返回的结果还可以增加edge来进行下一步的分流\r\n3. 从而降低模型需要长文本的缺陷\n\n算法架构：\n1. 问题拆分并进行计划执行，利用 RAG 进行计算\n2. 工具选择判断（选择），加载到 toollist\n3. 把 toolslist 返回到 executor-Agent 中进行执行，返回结果和计划\n4. 问题解决完成的就直接完成\n\n多个来回的 agent 判断速度太慢了，而且很麻烦性能优化也不够好，要做成接口很不方便\n\n开发总结：\n## 优点\n1. langgraph优势在于：长期存储工作流，实现多次交互\n2. 搭配langsmith能够试试看到工作流的调用情况\n3. 有非常多模板可以参考使用\n\n## 缺点\n1. 部署使用要把代码变得优雅优点难\n2. 如何实现thread的持久化也有点难\n3. 各个知识点的学习和灵活运用也有点难\n\n## 总结：\n1. 适合复杂项目，但是学习成本高，开发维护成本也高\n## ',
#    'priority': 0,
#    'status': 2,
#    'startDate': '2025-02-16 16:00:00',
#    'dueDate': '2025-02-16 16:00:00',
#    'projectId': '6669cdd9ebad9a000000039c',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-18T01:21:13.968+0000',
#    'createdTime': '2025-02-18 01:21:12',
#    'completedTime': '2025-02-18 01:21:12',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'o70fvzvb',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 196640}],
#  'uncompleted': [{'id': '67bae1ddebad9a000000037b',
#    'title': '测试时区',
#    'content': '',
#    'priority': 0,
#    'status': 0,
#    'startDate': '2025-02-22 16:00:00',
#    'dueDate': '2025-02-22 16:00:00',
#    'projectId': 'inbox1014518876',
#    'columnId': '65db218c7ae46e15dac5def8',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-23 08:52:45',
#    'createdTime': '2025-02-23 08:52:45',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'ai5ira71',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 9906344165376},
#   {'id': '67ae9663e37d5c00000001d6',
#    'title': '需求分析Agent',
#    'content': '',
#    'priority': 5,
#    'status': 0,
#    'startDate': '2025-02-22 16:00:00',
#    'dueDate': '2025-02-22 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-23 08:18:18',
#    'createdTime': '2025-02-14 01:03:31',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'w59stmy9',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 1236793779833},
#   {'id': '67b1959debad9a00010001cb',
#    'title': '飞书多维文档学习',
#    'content': '',
#    'priority': 0,
#    'status': 0,
#    'startDate': '2025-02-22 16:00:00',
#    'dueDate': '2025-02-22 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '65db218c7ae46e15dac5def8',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 23:53:27',
#    'createdTime': '2025-02-16 07:37:01',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'ypllb2k6',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2337379149433},
#   {'id': '67b19698ebad9a00010001eb',
#    'title': '前端UI设计技巧',
#    'content': '',
#    'priority': 0,
#    'status': 0,
#    'startDate': '2025-02-22 16:00:00',
#    'dueDate': '2025-02-22 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 23:53:28',
#    'createdTime': '2025-02-16 07:41:12',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'nsxsy7ov',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2337647584889},
#   {'id': '67b61265e37d5c00000000fd',
#    'title': '项目增删改查测试',
#    'content': '',
#    'priority': 5,
#    'status': 0,
#    'startDate': '2025-02-22 16:00:00',
#    'dueDate': '2025-02-22 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 23:53:22',
#    'createdTime': '2025-02-19 17:18:29',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '0yz0ngjp',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 805306368},
#   {'id': '67ba70e8ebad9a0000000242',
#    'title': '积木玩具反推+训练+构建自动生成3d的工作流',
#    'content': '',
#    'priority': 3,
#    'status': 0,
#    'startDate': '2025-02-22 16:00:00',
#    'dueDate': '2025-02-22 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-23 01:53:56',
#    'createdTime': '2025-02-23 00:50:48',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'x1lnreax',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 939524096},
#   {'id': '67b61f1b596486bc59feba77',
#    'title': 'ai 编码教程',
#    'content': '',
#    'priority': 1,
#    'status': 0,
#    'startDate': '2025-02-21 16:00:00',
#    'dueDate': '2025-02-21 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 23:53:25',
#    'createdTime': '2025-02-19 18:12:43',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'hcwt4g1k',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339392874108},
#   {'id': '67b61f3d596486bc59febab2',
#    'title': '思路',
#    'content': '# 如何成为面向AI编程高手？（Base Cursor）\n\nprompt的三大境界:（广告词）\n1. 知道你要什么？\n2. 理解你自己要什么？\n3. 挖掘你的底层需求\n\n写代码的几种情况\n1. 熟悉怎么写？\n2. 知道怎么写但没写过？\n3. 完全不知道怎么写？\n\n代码写错一直错',
#    'priority': 0,
#    'status': 0,
#    'startDate': '2025-02-21 16:00:00',
#    'dueDate': '2025-02-21 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'repeatFlag': '',
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-22 23:53:34',
#    'createdTime': '2025-02-19 18:13:17',
#    'completedTime': '2025-02-22 23:53:34',
#    'completedUserId': 1014518876,
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'klts78ep',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 2339419717653},
#   {'id': '67b195b2ebad9a00010001da',
#    'title': 'dify进行操作',
#    'content': '',
#    'priority': 0,
#    'status': 0,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-20 05:03:35',
#    'createdTime': '2025-02-16 07:37:22',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': '31ye1fsc',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 268435456},
#   {'id': '67b196a5ebad9a00010001f5',
#    'title': '小红书UI参考',
#    'content': '',
#    'priority': 0,
#    'status': 0,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-20 05:03:20',
#    'createdTime': '2025-02-16 07:41:25',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'hjw7dgct',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 268435456},
#   {'id': '67b196abebad9a00010001fd',
#    'title': 'uiverso.io+21st.dev',
#    'content': '',
#    'priority': 0,
#    'status': 0,
#    'startDate': '2025-02-19 16:00:00',
#    'dueDate': '2025-02-19 16:00:00',
#    'projectName': '🙊日常工作',
#    'projectId': '4024428bac6d182ac68da936',
#    'projectKind': 'TASK',
#    'columnId': '',
#    'tagDetails': [],
#    'kind': 'TEXT',
#    'isAllDay': True,
#    'items': [],
#    'progress': 0,
#    'modifiedTime': '2025-02-20 05:03:24',
#    'createdTime': '2025-02-16 07:41:31',
#    'isCompleted': False,
#    'creator': 1014518876,
#    'timeZone': 'Asia/Shanghai',
#    'isFloating': False,
#    'reminders': [],
#    'exDate': [],
#    'etag': 'cowlpxmx',
#    'deleted': 0,
#    'attachments': [],
#    'imgMode': 0,
#    'sortOrder': 268435456}]}

# %%
tasks = client.tasks.get_today_tasks()
tasks
# Out:
# {'completed': [], 'uncompleted': []}

# %%
import requests

def get_ticktick_token(email, password):
    login_url = "https://dida365.com/api/v2/user/signon?wc=true&remember=true"
    headers = {
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    payload = {
        "username": email,
        "password": password
    }
    
    response = requests.post(login_url, json=payload, headers=headers)
    if response.status_code == 200:
        token = response.cookies.get("t")
        return token
    else:
        raise Exception("登录失败，请检查账号密码")

# 替换为你的邮箱和密码
email = "523018705@qq.com"
password = "Xieyu120807!!!"
token = get_ticktick_token(email, password)
token
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 24
#      22 email = "523018705@qq.com"
#      23 password = "Xieyu120807!!!"
# ---> 24 token = get_ticktick_token(email, password)
#      25 token
#
# Cell In[2], line 19, in get_ticktick_token(email, password)
#      17     return token
#      18 else:
# ---> 19     raise Exception("登录失败，请检查账号密码")
#
# Exception: 登录失败，请检查账号密码

# %% [markdown]
# ## 获取任务全部信息（包括项目、清单、任务，标签，排序等）

# %%
def get_all_tasks(token, filters=None):
    """
    获取所有任务，支持多条件筛选
    
    参数说明:
    - token: 登录令牌
    - filters: 筛选条件字典，支持以下字段：
        - status: 任务状态 (0-未完成, 2-已完成)
        - priority: 优先级 (0-5)
        - project_id: 项目ID
        - tag_names: 标签名称列表
        - start_date: 开始时间
        - due_date: 截止时间
        
    返回:
    - list: 任务列表
    """
    tasks_url = "https://api.dida365.com/api/v2/batch/check/0"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    try:
        # 获取所有数据
        response = requests.get(tasks_url, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        # 获取任务列表
        tasks = data.get('syncTaskBean', {}).get('update', [])
        
        # 如果没有筛选条件，直接返回所有任务
        if not filters:
            return tasks
            
        # 应用筛选条件
        filtered_tasks = []
        for task in tasks:
            match = True
            
            # 状态筛选
            if 'status' in filters and task.get('status') != filters['status']:
                match = False
                
            # 优先级筛选
            if 'priority' in filters and task.get('priority') != filters['priority']:
                match = False
                
            # 项目筛选
            if 'project_id' in filters and task.get('projectId') != filters['project_id']:
                match = False
                
            # 标签筛选
            if 'tag_names' in filters:
                task_tags = set(task.get('tags', []))
                filter_tags = set(filters['tag_names'])
                if not (task_tags & filter_tags):  # 如果没有交集
                    match = False
                    
            # 开始时间筛选
            if 'start_date' in filters and task.get('startDate'):
                if task['startDate'] < filters['start_date']:
                    match = False
                    
            # 截止时间筛选
            if 'due_date' in filters and task.get('dueDate'):
                if task['dueDate'] > filters['due_date']:
                    match = False
            
            if match:
                filtered_tasks.append(task)
                
        return filtered_tasks
        
    except Exception as e:
        print(f"获取任务失败: {str(e)}")
        return []

def get_projects(token, filters=None):
    """
    获取项目列表，包含项目下的任务，支持多条件筛选
    
    参数说明:
    - token: 登录令牌
    - filters: 筛选条件字典，支持以下字段：
        - name: 项目名称
        - color: 项目颜色
        - group_id: 项目组ID
        - include_tasks: 是否包含任务（默认True）
        
    返回:
    - list: 项目列表，每个项目包含其任务列表
    """
    tasks_url = "https://api.dida365.com/api/v2/batch/check/0"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    try:
        # 获取所有数据
        response = requests.get(tasks_url, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        # 获取项目列表
        projects = data.get('projectProfiles', [])
        tasks = data.get('syncTaskBean', {}).get('update', [])
        
        # 处理项目数据
        result = []
        for project in projects:
            match = True
            
            # 应用筛选条件
            if filters:
                # 名称筛选
                if 'name' in filters and project.get('name') != filters['name']:
                    match = False
                    
                # 颜色筛选
                if 'color' in filters and project.get('color') != filters['color']:
                    match = False
                    
                # 项目组筛选
                if 'group_id' in filters and project.get('groupId') != filters['group_id']:
                    match = False
            
            if match:
                project_data = project.copy()
                
                # 添加任务列表（如果需要）
                # 如果filters为None或include_tasks未指定，默认为True
                if not filters or filters.get('include_tasks', True):
                    project_tasks = [
                        task for task in tasks
                        if task.get('projectId') == project['id']
                    ]
                    project_data['tasks'] = project_tasks
                    
                result.append(project_data)
                
        return result
        
    except Exception as e:
        print(f"获取项目失败: {str(e)}")
        return []

def get_tags(token, filters=None):
    """
    获取标签列表，包含标签下的任务，支持多条件筛选
    
    参数说明:
    - token: 登录令牌
    - filters: 筛选条件字典，支持以下字段：
        - names: 标签名称列表
        - color: 标签颜色
        - include_tasks: 是否包含任务（默认True）
        
    返回:
    - list: 标签列表，每个标签包含其任务列表
    """
    tasks_url = "https://api.dida365.com/api/v2/batch/check/0"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    try:
        # 获取所有数据
        response = requests.get(tasks_url, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        # 获取标签和任务列表
        tags = data.get('tags', [])
        tasks = data.get('syncTaskBean', {}).get('update', [])
        
        # 处理标签数据
        result = []
        for tag in tags:
            match = True
            
            # 应用筛选条件
            if filters:
                # 名称筛选
                if 'names' in filters and tag.get('name') not in filters['names']:
                    match = False
                    
                # 颜色筛选
                if 'color' in filters and tag.get('color') != filters['color']:
                    match = False
            
            if match:
                tag_data = tag.copy()
                
                # 添加任务列表（如果需要）
                # 如果filters为None或include_tasks未指定，默认为True
                if not filters or filters.get('include_tasks', True):
                    tag_tasks = [
                        task for task in tasks
                        if tag['name'] in task.get('tags', [])
                    ]
                    tag_data['tasks'] = tag_tasks
                    
                result.append(tag_data)
                
        return result
        
    except Exception as e:
        print(f"获取标签失败: {str(e)}")
        return []
    
# 1. 获取所有任务
all_tasks = get_all_tasks(token)

# 2. 获取特定状态的任务
completed_tasks = get_all_tasks(token, {'status': 2})

# 3. 获取高优先级且带特定标签的任务
important_tasks = get_all_tasks(token, {
    'priority': 5,
    'tag_names': ['重要', '紧急']
})

# 4. 获取所有项目及其任务
all_projects = get_projects(token)

# 5. 获取特定项目
specific_project = get_projects(token, {'name': '工作'})

# 6. 获取项目（不包含任务）
projects_only = get_projects(token, {'include_tasks': False})

# 7. 获取所有标签及其任务
all_tags = get_tags(token)

# 8. 获取特定标签
specific_tags = get_tags(token, {'names': ['重要', '紧急']})

# 9. 获取特定颜色的标签（不包含任务）
colored_tags = get_tags(token, {
    'color': '#FF0000',
    'include_tasks': False
})

# %% [markdown]
# ## 任务增删改查

# %%
# 定义创建任务的函数
def create_task(token, title, content="", startDate=None, dueDate=None, priority=0):
    """
    创建一个新的任务
    
    参数说明:
    - token: 登录令牌
    - title: 任务标题
    - content: 任务内容/备注
    - startDate: 开始时间 (ISO格式的字符串,如: "2023-12-25T00:00:00.000+0000")
    - dueDate: 截止时间 (ISO格式的字符串)
    - priority: 优先级 (0-最低, 1-低, 3-中, 5-高)
    """
    create_url = "https://api.dida365.com/api/v2/task"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    # 准备任务数据
    task_data = {
        "title": title,
        "content": content,
        "priority": priority
    }
    
    # 添加可选的时间参数
    if startDate:
        task_data["startDate"] = startDate
    if dueDate:
        task_data["dueDate"] = dueDate

    response = requests.post(create_url, json=task_data, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"创建任务失败: {response.text}")

# 定义更新任务状态的函数
def update_task_status(token, task_id, status=2):
    """
    更新任务的状态
    
    参数说明:
    - token: 登录令牌
    - task_id: 任务ID
    - status: 任务状态 (0-未完成, 2-已完成)
    """
    update_url = f"https://api.dida365.com/api/v2/task/{task_id}"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    # 获取当前任务信息
    response = requests.get(update_url, headers=headers)
    if response.status_code != 200:
        raise Exception("获取任务信息失败")
    print(response.json())
    # 更新任务状态
    task_data = response.json()
    task_data["status"] = status
    
    response = requests.put(update_url, json=task_data, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"更新任务状态失败: {response.text}")

# 定义删除任务的函数
def delete_task(token, task_id, project_id):
    """
    删除指定的任务
    
    参数说明:
    - token: 登录令牌
    - task_id: 要删除的任务ID
    - project_id: 任务所属的项目ID
    
    返回值:
    - bool: 删除是否成功
    """
    batch_url = "https://api.dida365.com/api/v2/batch/task"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    # 准备删除任务的数据
    delete_data = {
        "delete": [
            {
                "taskId": task_id,
                "projectId": project_id
            }
        ]
    }
    
    try:
        response = requests.post(batch_url, json=delete_data, headers=headers)
        if response.status_code == 200:
            return True
        else:
            error_msg = response.text if response.text else f"HTTP {response.status_code}"
            print(f"删除失败: {error_msg}")
            return False
    except requests.exceptions.RequestException as e:
        print(f"请求错误: {str(e)}")
        return False
    except Exception as e:
        print(f"删除任务时发生错误: {str(e)}")
        return False

# 示例使用
"""
# 创建新任务
new_task = create_task(
    token,
    title="测试任务",
    content="这是一个测试任务的描述",
    startDate="2023-12-25T00:00:00.000+0000",
    dueDate="2023-12-26T00:00:00.000+0000",
    priority=3
)

# 更新任务状态为已完成
updated_task = update_task_status(token, new_task['id'], status=2)

# 删除任务
is_deleted = delete_task(token, new_task['id'])
print(f"任务删除{'成功' if is_deleted else '失败'}")
"""
# new_task = create_task(
#     token,
#     title="测试任务1111",
#     content="这是一个测试任务的描述",
#     startDate="2023-12-25T00:00:00.000+0000",
#     dueDate="2023-12-26T00:00:00.000+0000",
#     priority=3
# )
# # updated_task = update_task_status(token, new_task['id'], status=2)
# delete_task(token, new_task['id'])


# 创建一个测试任务
new_task = create_task(
    token,
    title="测试任务1111",
    content="这是一个测试任务的描述",
    startDate="2023-12-25T00:00:00.000+0000",
    dueDate="2023-12-26T00:00:00.000+0000",
    priority=3
)

# 删除该任务
result = delete_task(token, new_task['id'],new_task['projectId'])
print(f"任务删除{'成功' if result else '失败'}")

# %% [markdown]
# ## 项目增删改查

# %%
def create_project(token, name, color="#FFD324", group_id=None, sort_order=None):
    """
    创建一个新的项目/清单
    
    参数说明:
    - token: 登录令牌
    - name: 项目名称
    - color: 项目颜色 (可选，默认为黄色)
    - group_id: 所属分组ID (可选)
    - sort_order: 排序顺序 (可选)
    
    返回:
    - dict: 创建成功的项目信息
    """
    create_url = "https://api.dida365.com/api/v2/project"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    # 准备项目数据
    project_data = {
        "name": name,
        "color": color,
        "inAll": True,
        "kind": "TASK",
        "viewMode": "list"
    }
    
    # 添加可选参数
    if group_id:
        project_data["groupId"] = group_id
    if sort_order:
        project_data["sortOrder"] = sort_order
    
    try:
        response = requests.post(create_url, json=project_data, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            raise Exception(f"创建项目失败: {response.text}")
    except Exception as e:
        print(f"创建项目时发生错误: {str(e)}")
        return None

def get_project(token, project_id):
    """
    获取项目详细信息
    
    参数说明:
    - token: 登录令牌
    - project_id: 项目ID
    
    返回:
    - dict: 项目详细信息
    """
    project_url = f"https://api.dida365.com/api/v2/project/{project_id}"
    headers = {
        "Cookie": f"t={token}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    try:
        response = requests.get(project_url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            raise Exception(f"获取项目信息失败: {response.text}")
    except Exception as e:
        print(f"获取项目信息时发生错误: {str(e)}")
        return None

def update_project(token, project_id, new_project, name=None, color=None, group_id=None):
    """
    更新项目信息
    
    参数说明:
    - token: 登录令牌
    - project_id: 项目ID
    - new_project: 当前项目信息
    - name: 新的项目名称 (可选)
    - color: 新的项目颜色 (可选)
    - group_id: 新的分组ID (可选)
    
    返回:
    - dict/bool: 更新后的项目信息或成功状态
    """
    update_url = f"https://api.dida365.com/api/v2/project/{project_id}"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    # 更新需要修改的字段
    if name:
        new_project["name"] = name
    if color:
        new_project["color"] = color
    if group_id:
        new_project["groupId"] = group_id
    
    try:
        response = requests.put(update_url, json=new_project, headers=headers)
        if response.status_code == 200:
            try:
                return response.json()  # 尝试解析JSON响应
            except ValueError:
                return True  # 如果没有JSON响应但状态码是200，返回True表示更新成功
        else:
            raise Exception(f"更新项目失败: {response.text}")
    except Exception as e:
        print(f"更新项目时发生错误: {str(e)}")
        return None

def delete_project(token, project_id):
    """
    删除指定的项目
    
    参数说明:
    - token: 登录令牌
    - project_id: 要删除的项目ID
    
    返回:
    - bool: 删除是否成功
    """
    delete_url = f"https://api.dida365.com/api/v2/project/{project_id}"
    headers = {
        "Cookie": f"t={token}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    try:
        response = requests.delete(delete_url, headers=headers)
        if response.status_code == 200:
            return True
        else:
            error_msg = response.text if response.text else f"HTTP {response.status_code}"
            print(f"删除失败: {error_msg}")
            return False
    except requests.exceptions.RequestException as e:
        print(f"请求错误: {str(e)}")
        return False
    except Exception as e:
        print(f"删除项目时发生错误: {str(e)}")
        return False

# 示例使用
"""
# 创建新项目
new_project = create_project(
    token,
    name="测试项目",
    color="#FFD324"
)

# 获取项目信息
project_info = get_project(token, new_project['id'])

# 更新项目
updated_project = update_project(
    token,
    project_id=new_project['id'],
    name="更新后的项目名称",
    color="#FF0000"
)

# 删除项目
is_deleted = delete_project(token, new_project['id'])
print(f"项目删除{'成功' if is_deleted else '失败'}")
"""

# %% [markdown]
# ## TAG增删改查

# %%
def get_all_data(token):
    """
    获取所有数据（包括标签、任务等）
    
    参数说明:
    - token: 登录令牌
    
    返回:
    - dict: 所有数据
    """
    check_url = "https://api.dida365.com/api/v2/batch/check/0"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    try:
        response = requests.get(check_url, headers=headers)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"获取数据失败: {str(e)}")
        return None

def create_tag(token, name, color="#FFD324"):
    """
    创建新标签
    
    参数说明:
    - token: 登录令牌
    - name: 标签名称
    - color: 标签颜色 (可选，默认黄色)
    
    返回:
    - dict: 创建的标签信息
    """
    batch_url = "https://api.dida365.com/api/v2/batch/tag"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    tag_data = {
        "add": [{
            "name": name,
            "label": name,
            "color": color,
            "sortOrder": -1099511693312,
            "sortType": "project",
            "parent": None,
            "type": 1  # 默认为个人标签
        }],
        "update": [],
        "delete": []
    }
    
    try:
        response = requests.post(batch_url, json=tag_data, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            raise Exception(f"创建标签失败: {response.text}")
    except Exception as e:
        print(f"创建标签时发生错误: {str(e)}")
        return None

def rename_tag(token, old_name, new_name):
    """
    重命名标签
    
    参数说明:
    - token: 登录令牌
    - old_name: 原标签名称
    - new_name: 新标签名称
    
    返回:
    - bool: 重命名是否成功
    """
    rename_url = "https://api.dida365.com/api/v2/tag/rename"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    rename_data = {
        "name": old_name,
        "newName": new_name
    }
    
    try:
        response = requests.put(rename_url, json=rename_data, headers=headers)
        if response.status_code == 200:
            return True
        else:
            raise Exception(f"重命名标签失败: {response.text}")
    except Exception as e:
        print(f"重命名标签时发生错误: {str(e)}")
        return False

def merge_tags(token, source_tag_name, target_tag_name):
    """
    合并标签
    
    参数说明:
    - token: 登录令牌
    - source_tag_name: 源标签名称（将被合并的标签）
    - target_tag_name: 目标标签名称（合并后保留的标签）
    
    返回:
    - bool: 合并是否成功
    """
    merge_url = "https://api.dida365.com/api/v2/tag/merge"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    merge_data = {
        "fromName": source_tag_name,
        "toName": target_tag_name
    }
    
    try:
        response = requests.put(merge_url, json=merge_data, headers=headers)
        if response.status_code == 200:
            return True
        else:
            raise Exception(f"合并标签失败: {response.text}")
    except Exception as e:
        print(f"合并标签时发生错误: {str(e)}")
        return False

def update_tag_type(token, tag_name, is_shared=False):
    """
    更新标签类型（个人/共同标签）
    
    参数说明:
    - token: 登录令牌
    - tag_name: 标签名称
    - is_shared: 是否为共同标签
    
    返回:
    - bool: 更新是否成功
    """
    all_data = get_all_data(token)
    if not all_data:
        return False
    
    target_tag = None
    for tag in all_data.get('tags', []):
        if tag.get('name') == tag_name:
            target_tag = tag
            break
    
    if not target_tag:
        print(f"标签 '{tag_name}' 不存在")
        return False
    
    batch_url = "https://api.dida365.com/api/v2/batch/tag"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    update_data = {
        "add": [],
        "update": [{
            **target_tag,
            "type": 2 if is_shared else 1
        }],
        "delete": []
    }
    
    try:
        response = requests.post(batch_url, json=update_data, headers=headers)
        if response.status_code == 200:
            return True
        else:
            raise Exception(f"更新标签类型失败: {response.text}")
    except Exception as e:
        print(f"更新标签类型时发生错误: {str(e)}")
        return False

def delete_tag(token, tag_name):
    """
    删除标签
    
    参数说明:
    - token: 登录令牌
    - tag_name: 标签名称
    
    返回:
    - bool: 删除是否成功
    """
    all_data = get_all_data(token)
    if not all_data:
        return False
    
    target_tag = None
    for tag in all_data.get('tags', []):
        if tag.get('name') == tag_name:
            target_tag = tag
            break
    
    if not target_tag:
        print(f"标签 '{tag_name}' 不存在")
        return False
    
    batch_url = "https://api.dida365.com/api/v2/batch/tag"
    headers = {
        "Cookie": f"t={token}",
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    delete_data = {
        "add": [],
        "update": [],
        "delete": [target_tag['id']]
    }
    
    try:
        response = requests.post(batch_url, json=delete_data, headers=headers)
        if response.status_code == 200:
            return True
        else:
            raise Exception(f"删除标签失败: {response.text}")
    except Exception as e:
        print(f"删除标签时发生错误: {str(e)}")
        return False

# 使用示例
def tag_operations_example(token):
    """
    标签操作示例
    """
    try:
        # 1. 创建标签
        print("创建标签...")
        tag1 = create_tag(token, "工作", color="#FF0000")
        if tag1:
            print("- 创建标签'工作'成功")
        
        # 2. 创建另一个标签用于合并
        print("\n创建用于合并的标签...")
        tag2 = create_tag(token, "临时", color="#0000FF")
        if tag2:
            print("- 创建标签'临时'成功")
        
        # 3. 重命名标签
        print("\n重命名标签...")
        if rename_tag(token, "临时", "待处理"):
            print("- 重命名标签为'待处理'成功")
        
        # 4. 更新标签类型
        print("\n更新标签类型...")
        if update_tag_type(token, "工作", is_shared=True):
            print("- 将'工作'标签设置为共同标签成功")
        
        # 5. 合并标签
        print("\n合并标签...")
        if merge_tags(token, "待处理", "工作"):
            print("- 将'待处理'标签合并到'工作'标签成功")
        
        # 6. 最后清理
        print("\n清理标签...")
        if delete_tag(token, "工作"):
            print("- 删除标签'工作'成功")
        
    except Exception as e:
        print(f"\n操作过程中发生错误: {str(e)}")

# 运行示例
# tag_operations_example(token)
# Out:
# 创建标签时发生错误: 创建标签失败: {"errorId":"cymao1lh@ctw6","errorCode":"unknown_exception","errorMessage":"Unknown exception","data":null}
